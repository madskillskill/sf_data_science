# %%
# Standard python libraries
import os
import time

# !pip install -r requirements.txt
# Essential DS libraries
import numpy as np
import pandas as pd

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import torch

# LightAutoML presets, task and report generation
from lightautoml.automl.presets.tabular_presets import TabularAutoML
from lightautoml.tasks import Task
# Out:
# Requirement already satisfied: alabaster==0.7.12 in c:\python\lib\site-packages (from -r requirements.txt (line 1)) (0.7.12)
# Requirement already satisfied: albumentations==1.2.1 in c:\python\lib\site-packages (from -r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: alembic==1.8.1 in c:\python\lib\site-packages (from -r requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: argon2-cffi==21.3.0 in c:\python\lib\site-packages (from -r requirements.txt (line 4)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\python\lib\site-packages (from -r requirements.txt (line 5)) (21.2.0)
# Requirement already satisfied: asttokens==2.0.8 in c:\python\lib\site-packages (from -r requirements.txt (line 6)) (2.0.8)
# Requirement already satisfied: atomicwrites==1.4.1 in c:\python\lib\site-packages (from -r requirements.txt (line 7)) (1.4.1)
# Requirement already satisfied: attrs==21.4.0 in c:\python\lib\site-packages (from -r requirements.txt (line 8)) (21.4.0)
# Requirement already satisfied: autopage==0.5.1 in c:\python\lib\site-packages (from -r requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: autowoe==1.3.2 in c:\python\lib\site-packages (from -r requirements.txt (line 10)) (1.3.2)
# Requirement already satisfied: Babel==2.10.3 in c:\python\lib\site-packages (from -r requirements.txt (line 11)) (2.10.3)
# Requirement already satisfied: backcall==0.2.0 in c:\python\lib\site-packages (from -r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.11.1 in c:\python\lib\site-packages (from -r requirements.txt (line 13)) (4.11.1)
# Requirement already satisfied: bleach==5.0.1 in c:\python\lib\site-packages (from -r requirements.txt (line 14)) (5.0.1)
# Requirement already satisfied: Brotli==1.0.9 in c:\python\lib\site-packages (from -r requirements.txt (line 15)) (1.0.9)
# Requirement already satisfied: catboost==1.0.6 in c:\python\lib\site-packages (from -r requirements.txt (line 16)) (1.0.6)
# Requirement already satisfied: category-encoders==2.5.0 in c:\python\lib\site-packages (from -r requirements.txt (line 17)) (2.5.0)
# Requirement already satisfied: certifi==2022.5.18.1 in c:\python\lib\site-packages (from -r requirements.txt (line 18)) (2022.5.18.1)
# Requirement already satisfied: cffi==1.15.1 in c:\python\lib\site-packages (from -r requirements.txt (line 19)) (1.15.1)
# Requirement already satisfied: chardet==4.0.0 in c:\python\lib\site-packages (from -r requirements.txt (line 20)) (4.0.0)
# Requirement already satisfied: charset-normalizer==2.0.12 in c:\python\lib\site-packages (from -r requirements.txt (line 21)) (2.0.12)
# Requirement already satisfied: click==8.1.3 in c:\python\lib\site-packages (from -r requirements.txt (line 22)) (8.1.3)
# Requirement already satisfied: cliff==4.0.0 in c:\python\lib\site-packages (from -r requirements.txt (line 23)) (4.0.0)
# Requirement already satisfied: cmaes==0.8.2 in c:\python\lib\site-packages (from -r requirements.txt (line 24)) (0.8.2)
# Requirement already satisfied: cmd2==2.4.2 in c:\python\lib\site-packages (from -r requirements.txt (line 25)) (2.4.2)
# Requirement already satisfied: colorama==0.4.5 in c:\python\lib\site-packages (from -r requirements.txt (line 26)) (0.4.5)
# Requirement already satisfied: colorlog==6.6.0 in c:\python\lib\site-packages (from -r requirements.txt (line 27)) (6.6.0)
# Requirement already satisfied: convertdate==2.4.0 in c:\python\lib\site-packages (from -r requirements.txt (line 28)) (2.4.0)
# Requirement already satisfied: cycler==0.11.0 in c:\python\lib\site-packages (from -r requirements.txt (line 29)) (0.11.0)
# Requirement already satisfied: Cython==0.29.28 in c:\python\lib\site-packages (from -r requirements.txt (line 30)) (0.29.28)
# Requirement already satisfied: dash==2.6.1 in c:\python\lib\site-packages (from -r requirements.txt (line 31)) (2.6.1)
# Requirement already satisfied: dash-bootstrap-components==1.2.1 in c:\python\lib\site-packages (from -r requirements.txt (line 32)) (1.2.1)
# Requirement already satisfied: dash-colorscales==0.0.4 in c:\python\lib\site-packages (from -r requirements.txt (line 33)) (0.0.4)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\python\lib\site-packages (from -r requirements.txt (line 34)) (2.0.0)
# Requirement already satisfied: dash-daq==0.5.0 in c:\python\lib\site-packages (from -r requirements.txt (line 35)) (0.5.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\python\lib\site-packages (from -r requirements.txt (line 36)) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\python\lib\site-packages (from -r requirements.txt (line 37)) (5.0.0)
# Requirement already satisfied: debugpy==1.6.3 in c:\python\lib\site-packages (from -r requirements.txt (line 38)) (1.6.3)
# Requirement already satisfied: decorator==5.1.1 in c:\python\lib\site-packages (from -r requirements.txt (line 39)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in c:\python\lib\site-packages (from -r requirements.txt (line 40)) (0.7.1)
# Requirement already satisfied: docutils==0.17.1 in c:\python\lib\site-packages (from -r requirements.txt (line 41)) (0.17.1)
# Requirement already satisfied: dtale==2.7.1 in c:\python\lib\site-packages (from -r requirements.txt (line 42)) (2.7.1)
# Requirement already satisfied: efficientnet-pytorch==0.7.1 in c:\python\lib\site-packages (from -r requirements.txt (line 43)) (0.7.1)
# Requirement already satisfied: entrypoints==0.4 in c:\python\lib\site-packages (from -r requirements.txt (line 44)) (0.4)
# Requirement already satisfied: et-xmlfile==1.1.0 in c:\python\lib\site-packages (from -r requirements.txt (line 45)) (1.1.0)
# Requirement already satisfied: executing==0.10.0 in c:\python\lib\site-packages (from -r requirements.txt (line 46)) (0.10.0)
# Requirement already satisfied: fastjsonschema==2.15.3 in c:\python\lib\site-packages (from -r requirements.txt (line 47)) (2.15.3)
# Requirement already satisfied: filelock==3.8.0 in c:\python\lib\site-packages (from -r requirements.txt (line 48)) (3.8.0)
# Requirement already satisfied: Flask==2.2.2 in c:\python\lib\site-packages (from -r requirements.txt (line 49)) (2.2.2)
# Requirement already satisfied: Flask-Compress==1.12 in c:\python\lib\site-packages (from -r requirements.txt (line 50)) (1.12)
# Requirement already satisfied: flask-ngrok==0.0.25 in c:\python\lib\site-packages (from -r requirements.txt (line 51)) (0.0.25)
# Requirement already satisfied: fonttools==4.33.3 in c:\python\lib\site-packages (from -r requirements.txt (line 52)) (4.33.3)
# Requirement already satisfied: future==0.18.2 in c:\python\lib\site-packages (from -r requirements.txt (line 53)) (0.18.2)
# Requirement already satisfied: gensim==4.2.0 in c:\python\lib\site-packages (from -r requirements.txt (line 54)) (4.2.0)
# Requirement already satisfied: graphviz==0.20.1 in c:\python\lib\site-packages (from -r requirements.txt (line 55)) (0.20.1)
# Requirement already satisfied: greenlet==1.1.3 in c:\python\lib\site-packages (from -r requirements.txt (line 56)) (1.1.3)
# Requirement already satisfied: hijri-converter==2.2.4 in c:\python\lib\site-packages (from -r requirements.txt (line 57)) (2.2.4)
# Requirement already satisfied: holidays==0.15 in c:\python\lib\site-packages (from -r requirements.txt (line 58)) (0.15)
# Requirement already satisfied: htmlmin==0.1.12 in c:\python\lib\site-packages (from -r requirements.txt (line 59)) (0.1.12)
# Requirement already satisfied: huggingface-hub==0.9.1 in c:\python\lib\site-packages (from -r requirements.txt (line 60)) (0.9.1)
# Requirement already satisfied: idna==3.3 in c:\python\lib\site-packages (from -r requirements.txt (line 61)) (3.3)
# Requirement already satisfied: ImageHash==4.2.1 in c:\python\lib\site-packages (from -r requirements.txt (line 62)) (4.2.1)
# Requirement already satisfied: imageio==2.21.1 in c:\python\lib\site-packages (from -r requirements.txt (line 63)) (2.21.1)
# Requirement already satisfied: imagesize==1.4.1 in c:\python\lib\site-packages (from -r requirements.txt (line 64)) (1.4.1)
# Requirement already satisfied: importlib-metadata==4.12.0 in c:\python\lib\site-packages (from -r requirements.txt (line 65)) (4.12.0)
# Requirement already satisfied: importlib-resources==5.9.0 in c:\python\lib\site-packages (from -r requirements.txt (line 66)) (5.9.0)
# Requirement already satisfied: iniconfig==1.1.1 in c:\python\lib\site-packages (from -r requirements.txt (line 67)) (1.1.1)
# Requirement already satisfied: ipykernel==6.15.1 in c:\python\lib\site-packages (from -r requirements.txt (line 68)) (6.15.1)
# Requirement already satisfied: ipython==8.4.0 in c:\python\lib\site-packages (from -r requirements.txt (line 69)) (8.4.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in c:\python\lib\site-packages (from -r requirements.txt (line 70)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.7.1 in c:\python\lib\site-packages (from -r requirements.txt (line 71)) (7.7.1)
# Requirement already satisfied: itsdangerous==2.1.2 in c:\python\lib\site-packages (from -r requirements.txt (line 72)) (2.1.2)
# Requirement already satisfied: jedi==0.18.1 in c:\python\lib\site-packages (from -r requirements.txt (line 73)) (0.18.1)
# Requirement already satisfied: Jinja2==3.1.2 in c:\python\lib\site-packages (from -r requirements.txt (line 74)) (3.1.2)
# Requirement already satisfied: joblib==1.1.0 in c:\python\lib\site-packages (from -r requirements.txt (line 75)) (1.1.0)
# Requirement already satisfied: json2html==1.3.0 in c:\python\lib\site-packages (from -r requirements.txt (line 76)) (1.3.0)
# Requirement already satisfied: jsonschema==4.5.1 in c:\python\lib\site-packages (from -r requirements.txt (line 77)) (4.5.1)
# Requirement already satisfied: jupyter-core==4.11.1 in c:\python\lib\site-packages (from -r requirements.txt (line 78)) (4.11.1)
# Requirement already satisfied: jupyter_client==7.3.5 in c:\python\lib\site-packages (from -r requirements.txt (line 79)) (7.3.5)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in c:\python\lib\site-packages (from -r requirements.txt (line 80)) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets==1.1.1 in c:\python\lib\site-packages (from -r requirements.txt (line 81)) (1.1.1)
# Requirement already satisfied: kaleido==0.2.1 in c:\python\lib\site-packages (from -r requirements.txt (line 82)) (0.2.1)
# Requirement already satisfied: kiwisolver==1.4.2 in c:\python\lib\site-packages (from -r requirements.txt (line 83)) (1.4.2)
# Requirement already satisfied: korean-lunar-calendar==0.2.1 in c:\python\lib\site-packages (from -r requirements.txt (line 84)) (0.2.1)
# Requirement already satisfied: lightautoml==0.2.15 in c:\python\lib\site-packages (from -r requirements.txt (line 85)) (0.2.15)
# Requirement already satisfied: lightgbm==2.3.1 in c:\python\lib\site-packages (from -r requirements.txt (line 86)) (2.3.1)
# Requirement already satisfied: log-calls==0.3.2 in c:\python\lib\site-packages (from -r requirements.txt (line 87)) (0.3.2)
# Requirement already satisfied: lxml==4.9.1 in c:\python\lib\site-packages (from -r requirements.txt (line 88)) (4.9.1)
# Requirement already satisfied: lz4==4.0.2 in c:\python\lib\site-packages (from -r requirements.txt (line 89)) (4.0.2)
# Requirement already satisfied: Mako==1.2.1 in c:\python\lib\site-packages (from -r requirements.txt (line 90)) (1.2.1)
# Requirement already satisfied: MarkupSafe==2.1.1 in c:\python\lib\site-packages (from -r requirements.txt (line 91)) (2.1.1)
# Requirement already satisfied: matplotlib==3.5.2 in c:\python\lib\site-packages (from -r requirements.txt (line 92)) (3.5.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\python\lib\site-packages (from -r requirements.txt (line 93)) (0.1.6)
# Requirement already satisfied: missingno==0.4.2 in c:\python\lib\site-packages (from -r requirements.txt (line 94)) (0.4.2)
# Requirement already satisfied: mistune==0.8.4 in c:\python\lib\site-packages (from -r requirements.txt (line 95)) (0.8.4)
# Requirement already satisfied: multimethod==1.8 in c:\python\lib\site-packages (from -r requirements.txt (line 96)) (1.8)
# Requirement already satisfied: nbclient==0.6.6 in c:\python\lib\site-packages (from -r requirements.txt (line 97)) (0.6.6)
# Requirement already satisfied: nbconvert==6.5.3 in c:\python\lib\site-packages (from -r requirements.txt (line 98)) (6.5.3)
# Requirement already satisfied: nbformat==5.4.0 in c:\python\lib\site-packages (from -r requirements.txt (line 99)) (5.4.0)
# Requirement already satisfied: nest-asyncio==1.5.5 in c:\python\lib\site-packages (from -r requirements.txt (line 100)) (1.5.5)
# Requirement already satisfied: networkx==2.8.5 in c:\python\lib\site-packages (from -r requirements.txt (line 101)) (2.8.5)
# Requirement already satisfied: nltk==3.7 in c:\python\lib\site-packages (from -r requirements.txt (line 102)) (3.7)
# Requirement already satisfied: notebook==6.4.12 in c:\python\lib\site-packages (from -r requirements.txt (line 103)) (6.4.12)
# Requirement already satisfied: numpy==1.22.3 in c:\python\lib\site-packages (from -r requirements.txt (line 104)) (1.22.3)
# Requirement already satisfied: opencv-python==4.6.0.66 in c:\python\lib\site-packages (from -r requirements.txt (line 105)) (4.6.0.66)
# Requirement already satisfied: opencv-python-headless==4.6.0.66 in c:\python\lib\site-packages (from -r requirements.txt (line 106)) (4.6.0.66)
# Requirement already satisfied: openpyxl==3.0.10 in c:\python\lib\site-packages (from -r requirements.txt (line 107)) (3.0.10)
# Requirement already satisfied: optuna==2.10.1 in c:\python\lib\site-packages (from -r requirements.txt (line 108)) (2.10.1)
# Requirement already satisfied: packaging==21.3 in c:\python\lib\site-packages (from -r requirements.txt (line 109)) (21.3)
# Requirement already satisfied: pandas==1.4.2 in c:\python\lib\site-packages (from -r requirements.txt (line 110)) (1.4.2)
# Requirement already satisfied: pandas-profiling==3.2.0 in c:\python\lib\site-packages (from -r requirements.txt (line 111)) (3.2.0)
# Requirement already satisfied: pandocfilters==1.5.0 in c:\python\lib\site-packages (from -r requirements.txt (line 112)) (1.5.0)
# Requirement already satisfied: parso==0.8.3 in c:\python\lib\site-packages (from -r requirements.txt (line 113)) (0.8.3)
# Requirement already satisfied: patsy==0.5.2 in c:\python\lib\site-packages (from -r requirements.txt (line 114)) (0.5.2)
# Requirement already satisfied: pbr==5.10.0 in c:\python\lib\site-packages (from -r requirements.txt (line 115)) (5.10.0)
# Requirement already satisfied: phik==0.12.2 in c:\python\lib\site-packages (from -r requirements.txt (line 116)) (0.12.2)
# Requirement already satisfied: pickleshare==0.7.5 in c:\python\lib\site-packages (from -r requirements.txt (line 117)) (0.7.5)
# Requirement already satisfied: Pillow==9.1.0 in c:\python\lib\site-packages (from -r requirements.txt (line 118)) (9.1.0)
# Requirement already satisfied: plotly==5.7.0 in c:\python\lib\site-packages (from -r requirements.txt (line 119)) (5.7.0)
# Requirement already satisfied: pluggy==1.0.0 in c:\python\lib\site-packages (from -r requirements.txt (line 120)) (1.0.0)
# Requirement already satisfied: poetry-core==1.0.8 in c:\python\lib\site-packages (from -r requirements.txt (line 121)) (1.0.8)
# Requirement already satisfied: prettytable==3.4.0 in c:\python\lib\site-packages (from -r requirements.txt (line 122)) (3.4.0)
# Requirement already satisfied: prometheus-client==0.14.1 in c:\python\lib\site-packages (from -r requirements.txt (line 123)) (0.14.1)
# Requirement already satisfied: prompt-toolkit==3.0.30 in c:\python\lib\site-packages (from -r requirements.txt (line 124)) (3.0.30)
# Requirement already satisfied: psutil==5.9.1 in c:\python\lib\site-packages (from -r requirements.txt (line 125)) (5.9.1)
# Requirement already satisfied: pure-eval==0.2.2 in c:\python\lib\site-packages (from -r requirements.txt (line 126)) (0.2.2)
# Requirement already satisfied: py==1.11.0 in c:\python\lib\site-packages (from -r requirements.txt (line 127)) (1.11.0)
# Requirement already satisfied: pycparser==2.21 in c:\python\lib\site-packages (from -r requirements.txt (line 128)) (2.21)
# Requirement already satisfied: pydantic==1.9.2 in c:\python\lib\site-packages (from -r requirements.txt (line 129)) (1.9.2)
# Requirement already satisfied: Pygments==2.13.0 in c:\python\lib\site-packages (from -r requirements.txt (line 130)) (2.13.0)
# Requirement already satisfied: PyMeeus==0.5.11 in c:\python\lib\site-packages (from -r requirements.txt (line 131)) (0.5.11)
# Requirement already satisfied: pyparsing==3.0.9 in c:\python\lib\site-packages (from -r requirements.txt (line 132)) (3.0.9)
# Requirement already satisfied: pyperclip==1.8.2 in c:\python\lib\site-packages (from -r requirements.txt (line 133)) (1.8.2)
# Requirement already satisfied: pyreadline3==3.4.1 in c:\python\lib\site-packages (from -r requirements.txt (line 134)) (3.4.1)
# Requirement already satisfied: pyrsistent==0.18.1 in c:\python\lib\site-packages (from -r requirements.txt (line 135)) (0.18.1)
# Requirement already satisfied: pytest==7.1.2 in c:\python\lib\site-packages (from -r requirements.txt (line 136)) (7.1.2)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\python\lib\site-packages (from -r requirements.txt (line 137)) (2.8.2)
# Requirement already satisfied: pytz==2022.1 in c:\python\lib\site-packages (from -r requirements.txt (line 138)) (2022.1)
# Requirement already satisfied: PyWavelets==1.3.0 in c:\python\lib\site-packages (from -r requirements.txt (line 139)) (1.3.0)
# Requirement already satisfied: pywin32==304 in c:\python\lib\site-packages (from -r requirements.txt (line 140)) (304)
# Requirement already satisfied: pywinpty==2.0.7 in c:\python\lib\site-packages (from -r requirements.txt (line 141)) (2.0.7)
# Requirement already satisfied: PyYAML==6.0 in c:\python\lib\site-packages (from -r requirements.txt (line 142)) (6.0)
# Requirement already satisfied: pyzmq==23.2.1 in c:\python\lib\site-packages (from -r requirements.txt (line 143)) (23.2.1)
# Requirement already satisfied: qudida==0.0.4 in c:\python\lib\site-packages (from -r requirements.txt (line 144)) (0.0.4)
# Requirement already satisfied: regex==2022.8.17 in c:\python\lib\site-packages (from -r requirements.txt (line 145)) (2022.8.17)
# Requirement already satisfied: requests==2.27.1 in c:\python\lib\site-packages (from -r requirements.txt (line 146)) (2.27.1)
# Requirement already satisfied: schedule==1.1.0 in c:\python\lib\site-packages (from -r requirements.txt (line 147)) (1.1.0)
# Requirement already satisfied: scikit-image==0.19.3 in c:\python\lib\site-packages (from -r requirements.txt (line 148)) (0.19.3)
# Requirement already satisfied: scikit-learn==1.1.2 in c:\python\lib\site-packages (from -r requirements.txt (line 149)) (1.1.2)
# Requirement already satisfied: scipy==1.8.0 in c:\python\lib\site-packages (from -r requirements.txt (line 150)) (1.8.0)
# Requirement already satisfied: seaborn==0.11.2 in c:\python\lib\site-packages (from -r requirements.txt (line 151)) (0.11.2)
# Requirement already satisfied: Send2Trash==1.8.0 in c:\python\lib\site-packages (from -r requirements.txt (line 152)) (1.8.0)
# Requirement already satisfied: six==1.16.0 in c:\python\lib\site-packages (from -r requirements.txt (line 153)) (1.16.0)
# Requirement already satisfied: smart-open==6.1.0 in c:\python\lib\site-packages (from -r requirements.txt (line 154)) (6.1.0)
# Requirement already satisfied: snowballstemmer==2.2.0 in c:\python\lib\site-packages (from -r requirements.txt (line 155)) (2.2.0)
# Requirement already satisfied: soupsieve==2.3.2.post1 in c:\python\lib\site-packages (from -r requirements.txt (line 156)) (2.3.2.post1)
# Requirement already satisfied: Sphinx==5.1.1 in c:\python\lib\site-packages (from -r requirements.txt (line 157)) (5.1.1)
# Requirement already satisfied: sphinx-rtd-theme==1.0.0 in c:\python\lib\site-packages (from -r requirements.txt (line 158)) (1.0.0)
# Requirement already satisfied: sphinxcontrib-applehelp==1.0.2 in c:\python\lib\site-packages (from -r requirements.txt (line 159)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp==1.0.2 in c:\python\lib\site-packages (from -r requirements.txt (line 160)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-htmlhelp==2.0.0 in c:\python\lib\site-packages (from -r requirements.txt (line 161)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-jsmath==1.0.1 in c:\python\lib\site-packages (from -r requirements.txt (line 162)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp==1.0.3 in c:\python\lib\site-packages (from -r requirements.txt (line 163)) (1.0.3)
# Requirement already satisfied: sphinxcontrib-serializinghtml==1.1.5 in c:\python\lib\site-packages (from -r requirements.txt (line 164)) (1.1.5)
# Requirement already satisfied: SQLAlchemy==1.4.40 in c:\python\lib\site-packages (from -r requirements.txt (line 165)) (1.4.40)
# Requirement already satisfied: squarify==0.4.3 in c:\python\lib\site-packages (from -r requirements.txt (line 166)) (0.4.3)
# Requirement already satisfied: stack-data==0.4.0 in c:\python\lib\site-packages (from -r requirements.txt (line 167)) (0.4.0)
# Requirement already satisfied: statistics==1.0.3.5 in c:\python\lib\site-packages (from -r requirements.txt (line 168)) (1.0.3.5)
# Requirement already satisfied: statsmodels==0.13.2 in c:\python\lib\site-packages (from -r requirements.txt (line 169)) (0.13.2)
# Requirement already satisfied: stevedore==4.0.0 in c:\python\lib\site-packages (from -r requirements.txt (line 170)) (4.0.0)
# Requirement already satisfied: StrEnum==0.4.8 in c:\python\lib\site-packages (from -r requirements.txt (line 171)) (0.4.8)
# Requirement already satisfied: strsimpy==0.2.1 in c:\python\lib\site-packages (from -r requirements.txt (line 172)) (0.2.1)
# Requirement already satisfied: sweetviz==2.1.4 in c:\python\lib\site-packages (from -r requirements.txt (line 173)) (2.1.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\python\lib\site-packages (from -r requirements.txt (line 174)) (0.2.0)
# Requirement already satisfied: tenacity==8.0.1 in c:\python\lib\site-packages (from -r requirements.txt (line 175)) (8.0.1)
# Requirement already satisfied: terminado==0.15.0 in c:\python\lib\site-packages (from -r requirements.txt (line 176)) (0.15.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in c:\python\lib\site-packages (from -r requirements.txt (line 177)) (3.1.0)
# Requirement already satisfied: tifffile==2022.8.12 in c:\python\lib\site-packages (from -r requirements.txt (line 178)) (2022.8.12)
# Requirement already satisfied: tinycss2==1.1.1 in c:\python\lib\site-packages (from -r requirements.txt (line 179)) (1.1.1)
# Requirement already satisfied: tokenizers==0.12.1 in c:\python\lib\site-packages (from -r requirements.txt (line 180)) (0.12.1)
# Requirement already satisfied: tomli==2.0.1 in c:\python\lib\site-packages (from -r requirements.txt (line 181)) (2.0.1)
# Requirement already satisfied: torch==1.12.1 in c:\python\lib\site-packages (from -r requirements.txt (line 182)) (1.12.1)
# Requirement already satisfied: torchvision==0.13.1 in c:\python\lib\site-packages (from -r requirements.txt (line 183)) (0.13.1)
# Requirement already satisfied: tornado==6.2 in c:\python\lib\site-packages (from -r requirements.txt (line 184)) (6.2)
# Requirement already satisfied: tqdm==4.64.0 in c:\python\lib\site-packages (from -r requirements.txt (line 185)) (4.64.0)
# Requirement already satisfied: traitlets==5.3.0 in c:\python\lib\site-packages (from -r requirements.txt (line 186)) (5.3.0)
# Requirement already satisfied: transformers==4.21.2 in c:\python\lib\site-packages (from -r requirements.txt (line 187)) (4.21.2)
# Requirement already satisfied: typing_extensions==4.3.0 in c:\python\lib\site-packages (from -r requirements.txt (line 188)) (4.3.0)
# Requirement already satisfied: urllib3==1.26.9 in c:\python\lib\site-packages (from -r requirements.txt (line 189)) (1.26.9)
# Requirement already satisfied: visions==0.7.4 in c:\python\lib\site-packages (from -r requirements.txt (line 190)) (0.7.4)
# Requirement already satisfied: wcwidth==0.2.5 in c:\python\lib\site-packages (from -r requirements.txt (line 191)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in c:\python\lib\site-packages (from -r requirements.txt (line 192)) (0.5.1)
# Requirement already satisfied: Werkzeug==2.2.2 in c:\python\lib\site-packages (from -r requirements.txt (line 193)) (2.2.2)
# Requirement already satisfied: widgetsnbextension==3.6.1 in c:\python\lib\site-packages (from -r requirements.txt (line 194)) (3.6.1)
# Requirement already satisfied: xarray==2022.6.0 in c:\python\lib\site-packages (from -r requirements.txt (line 195)) (2022.6.0)
# Requirement already satisfied: xlrd==2.0.1 in c:\python\lib\site-packages (from -r requirements.txt (line 196)) (2.0.1)
# Requirement already satisfied: zipp==3.8.1 in c:\python\lib\site-packages (from -r requirements.txt (line 197)) (3.8.1)
# Requirement already satisfied: setuptools>=18.5 in c:\python\lib\site-packages (from ipython==8.4.0->-r requirements.txt (line 69)) (58.1.0)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\SF\sf_data_science\KAGGLE\KAGGLE.ipynb Ячейка 1 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/KAGGLE/KAGGLE.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> get_ipython().system('pip install -r requirements.txt')
#       <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/KAGGLE/KAGGLE.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> # Essential DS libraries
# ----> <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/KAGGLE/KAGGLE.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/KAGGLE/KAGGLE.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> import pandas as pd
#      <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/KAGGLE/KAGGLE.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> from sklearn.metrics import mean_absolute_error
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#from lightautoml.automl.presets.tabular_presets import TabularAutoML
#from lightautoml.tasks import Task

# %%
N_THREADS = 4
N_FOLDS = 5
RANDOM_STATE = 42
TEST_SIZE = 0.2
TIMEOUT = 600 # equal to 10 minutes
TARGET_NAME = 'final_price'

# %%
np.random.seed(RANDOM_STATE)
torch.set_num_threads(N_THREADS)

# %%
INPUT_DIR = '/data/'

# %%
train_data = pd.read_csv('data/train_data.csv')
print(train_data.shape)
train_data.head()
# Out:
# (35000, 15)
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0       0               TOYOTA        Aqua s            Sedan
# 1       1        MERCEDES-BENZ         C 220            Sedan
# 2       2              HYUNDAI      Veloster        Hatchback
# 3       3              HYUNDAI      Santa FE             Jeep
# 4       4               TOYOTA           CHR             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           133000          2014            Automatic       4/5
# 1            24500          2010               Manual       4/5
# 2            31000          2016            Tiptronic       2/3
# 3           115459          2015            Automatic       4/5
# 4            18950          2019            Automatic       4/5
#
#                   wheels vehicle_color vehicle_interior_color  \
# 0    Right-hand drive          Silver                  Black
# 1           Left wheel         Silver                  Black
# 2           Left wheel         Silver                  Black
# 3           Left wheel           Blue                  Black
# 4           Left wheel          Black                     NaN
#
#                car_vin  car_leather_interior deal_type  final_price
# 0                  NaN                     0  For Sale       3650.0
# 1                  NaN                     0  For Sale       6800.0
# 2   KMHTC6AE3GU293912                      1  For Sale       6300.0
# 3                  NaN                     1  For Sale      14488.0
# 4   JTNKHMBX7K1030253                      1  For Sale       5000.0

# %%
test_data = pd.read_csv('data/test_data.csv')
print(test_data.shape)
test_data.head()
# Out:
# (10697, 14)
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0   35000               TOYOTA         Prius        Hatchback
# 1   35001              HYUNDAI       Elantra            Sedan
# 2   35002                LEXUS        NX 300             Jeep
# 3   35003                LEXUS       CT 200h        Hatchback
# 4   35004               TOYOTA         RAV 4             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           323733          2012            Automatic       4/5
# 1           112000          2013            Tiptronic       4/5
# 2            16920          2018            Automatic       NaN
# 3           302742          2012            Automatic       4/5
# 4             1800          2002               Manual       4/5
#
#            wheels vehicle_color vehicle_interior_color              car_vin  \
# 0    Left wheel           Grey                  Black    JTDKN3DU6C5439638
# 1    Left wheel           Grey                  Black            SURATSHIA
# 2    Left wheel          Brown                     NaN   JTJYARBZ5J2104521
# 3    Left wheel          White                     NaN   JTHKD5BH4C2070945
# 4    Left wheel         Silver                  Black                   NaN
#
#    car_leather_interior deal_type
# 0                     1  For Sale
# 1                     1  For Sale
# 2                     1  For Sale
# 3                     1  For Sale
# 4                     0  For Sale

# %%
submission = pd.read_csv('data/sample_submission.csv')
print(submission.shape)
submission.head()
# Out:
# (10697, 2)
#    row_ID  final_price
# 0   35000            0
# 1   35001            0
# 2   35002            0
# 3   35003            0
# 4   35004            0

# %%
# %%time

def create_expert_feats(data):
    pass

create_expert_feats(train_data)
create_expert_feats(test_data)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
tr_data, te_data = train_test_split(
    train_data, 
    test_size=TEST_SIZE, 
    random_state=RANDOM_STATE
)

print(f'Data splitted. Parts sizes: tr_data = {tr_data.shape}, te_data = {te_data.shape}')

tr_data.head()
# Out:
# Data splitted. Parts sizes: tr_data = (28000, 15), te_data = (7000, 15)
#        row_ID vehicle_manufacturer   vehicle_model vehicle_category  \
# 18788   18788              HYUNDAI        Santa FE             Jeep
# 776       776              HYUNDAI        Santa FE             Jeep
# 480       480                  BMW  X5 XDRIVE35 D              Jeep
# 30078   30078             CHRYSLER             300            Sedan
# 29115   29115               TOYOTA         4Runner             Jeep
#
#        current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 18788           177719          2010            Automatic       4/5
# 776             143166          2011            Automatic       4/5
# 480             149000          2015            Tiptronic       4/5
# 30078           133904          2014            Automatic       4/5
# 29115                0          2018            Automatic       4/5
#
#                wheels vehicle_color vehicle_interior_color car_vin  \
# 18788    Left wheel         Silver                  Black      NaN
# 776      Left wheel           Grey                  Black      NaN
# 480      Left wheel          Black                  Black      NaN
# 30078    Left wheel         Silver                  Black      NaN
# 29115    Left wheel          Black                  Black      NaN
#
#        car_leather_interior deal_type  final_price
# 18788                     1  For Sale       7464.0
# 776                       1  For Sale       5959.0
# 480                       1  For Sale      23900.0
# 30078                     1  For Sale       1750.0
# 29115                     1  For Sale        100.0
