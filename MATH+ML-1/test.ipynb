# %%
# importing the required libraries
import matplotlib.pyplot as plt
import numpy as np
 
# define data values
x = np.array([1, 2, 3, 4])  # X-axis points
y = x*2  # Y-axis points
 
plt.plot(x, y)  # Plot the chart
plt.show()  # display

# %%
x = np.array([1, 4])  # X-axis points
y = x  # Y-axis points

plt.plot(x, y)  # Plot the chart
plt.show()  # display

# %%
import math
import random

# %%
def rg():
    x = random.randrange(1, 10)
    y = random.randrange(1, 10)
    return [x,y]

first = rg()
second = rg()
third = rg()

print ('First', first, '--- Second', second)
plt.plot([first[0], second[0]], [first[1], second[1]])  # Plot the chart
plt.show()

x_dif = (first[0] - second[0])
y_dif = (first[1] - second[1])


distance = math.sqrt(x_dif**2 + y_dif**2)
print('Distance:', distance)

# %%
# %matplotlib widget 
# from matplotlib import animation

# fig = plt.figure()
# ax = fig.add_subplot(projection='3d')

# num_of_points = 50
# num_of_frames = 200

# t = np.linspace(0, 2*np.pi, num_of_frames, endpoint=False)[:,None] + np.linspace(0,2*np.pi, num_of_points, endpoint=False)[None, :]
# x = np.cos(t)
# y = np.sin(t)
# z = np.sin(t)*np.cos(t)

# points, = ax.plot([], [], [], 'o')

# def update_points(n):
#     points.set_data(np.array([x[n, :], y[n, :], ]))
#     points.set_3d_properties(z[n, :], 'z')
#     return points,

# ax.set_xlim([-1.5, 1.5])
# ax.set_ylim([-1.5, 1.5])
# ax.set_zlim([-1.5, 1.5])

# ani = animation.FuncAnimation(fig, update_points, num_of_frames, interval = 100, blit=True, repeat = True)
# plt.show()

# %%
from matplotlib.pyplot import figure
center = [5,5]

fig = plt.figure()
figure(figsize=(5, 5), dpi=80)


def rg():
    x = random.randrange(1, 10)
    y = random.randrange(1, 10)
    return [x,y]

point = rg()

plt.grid(True)

print ('center', center, '--- point', point)
plt.plot([center[0], point[0]], [center[1], point[1]])  # Plot the chart
plt.axis('equal')
plt.axis([0, 10, 0, 10])
plt.show()


x_dif = (center[0] - point[0])
y_dif = (center[1] - point[1])

# fig.set_xlim([-10, 10])
# fig.set_ylim([-10, 10])

distance = math.sqrt(x_dif**2 + y_dif**2)
print('Distance:', distance)

# %%
# %matplotlib widget 
# from matplotlib import animation
# from matplotlib.pyplot import figure

# center = [0,0]

# fig = plt.figure()
# figure(figsize=(5, 5), dpi=80)
# ax = fig.add_subplot()

# num_of_frames = 200


# def rg():
#     x = random.randrange(-10, 10)
#     y = random.randrange(-10, 10)
#     return [x,y]

# def update_axis(n):
#     if n == 10:
#         n -= random.randint(0,1)
#         return n
#     elif n == -10:
#         n += random.randint(0,1)
#         return n
#     else:
#         n += random.randint(-1,1)
        
# def update_point(point):
#     point_x = update_axis(point[0])
#     point_y = update_axis(point[1])
#     point = [point_x, point_y]
#     return point


# point = rg()

# points, = ax.plot([],[], 'x')

# def update_points(n):
#     points.set_data

# plt.grid(True)

# print ('center', center, '--- point', point)
# # plt.plot([center[0], point[0]], [center[1], point[1]])  # Plot the chart
# plt.axis('equal')
# plt.axis([-10, 10, -10, 10])
# ani = animation.FuncAnimation(fig, update_point(point), num_of_frames, interval = 100, blit = True, repeat = True)
# plt.show()


# x_dif = (center[0] - point[0])
# y_dif = (center[1] - point[1])

# distance = math.sqrt(x_dif**2 + y_dif**2)
# print('Distance:', distance)

# %%
# import matplotlib.pyplot as plt
# from matplotlib.animation import FuncAnimation
# import numpy as np

# # Create a figure and axis
# fig, ax = plt.subplots()

# # Create a line plot
# x = np.linspace(0, 2 * np.pi, 100)
# y = np.sin(x)
# line, = ax.plot(x, y)

# # Function to update the plot during animation
# def update(frame):
#     # Rotate the line plot
#     line.set_ydata(np.sin(x + frame/10))

#     return line,

# # Create the animation
# animation = FuncAnimation(fig, update, frames=100, interval=50, blit=True)

# # Show the plot
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import matplotlib.animation as animation
# import numpy as np

# # Create a figure and axis
# fig, ax = plt.subplots()

# # Set the axis limits
# ax.set_xlim([-10, 10])
# ax.set_ylim([-10, 10])

# # Create a dot at the initial position
# dot, = ax.plot([], [], 'ro')

# # Initialize the dot's position and distance
# position = np.array([0, 0], dtype=float)
# distance = np.linalg.norm(position)

# # Function to update the dot's position
# def update_dot(frame):
#     global position, distance
    
#     # Update the dot's position
#     position[0] = np.sin(np.radians(frame))
#     position[1] = np.cos(np.radians(frame))
    
#     # Update the dot's distance from the center
#     distance = np.linalg.norm(position)
    
#     # Update the dot's coordinates
#     dot.set_data(position[0], position[1])
    
#     # Print the dot's distance from the center
#     print("Distance from center:", distance)
    
#     return dot,

# # Function to initialize the animation
# def init():
#     dot.set_data([], [])
#     return dot,

# # Create the animation
# ani = animation.FuncAnimation(fig, update_dot, frames=np.arange(0, 360, 1), 
#                               init_func=init, blit=True)

# # Show the plot
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.animation as animation

# # Set up the figure and axis
# fig, ax = plt.subplots()
# ax.set_xlim(-10, 10)
# ax.set_ylim(-10, 10)

# # Initialize the dot position
# dot, = ax.plot([], [], 'ro')

# # Initialize the line
# line, = ax.plot([], [], 'r--')

# # Initialize the center point
# center = (0, 0)

# # Function to update the animation
# def update(frame):
#     # Generate random movement for the dot
#     dx, dy = np.random.uniform(-1, 1, 2)

#     # Update the dot position
#     dot.set_data(center[0] + dx, center[1] + dy)

#     # Calculate the distance between the center and the dot
#     distance = np.sqrt(dx**2 + dy**2)

#     # Update the line between the center and the dot
#     line.set_data([center[0], center[0] + dx], [center[1], center[1] + dy])

#     return dot, line

# # Create the animation
# ani = animation.FuncAnimation(fig, update, frames=100, interval=100, blit=True)

# # Show the plot
# plt.show()

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.MatplotlibDeprecationWarning)

craze = 0
steps = 0
x = np.random.uniform(-1, 1)
y = np.random.uniform(-1, 1)
# Create a figure and axis
fig, ax = plt.subplots()

# Set the limits of the plot
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])


distance_text = ''
# Create a dot object
dot, = ax.plot([], [], 'ro')

# Create a line object
line, = ax.plot([], [], 'b-')

ax.set_title('Random wondering', 
             fontsize = 14, fontweight ='bold') 
distance_text = ax.text(0, 1, s='', transform=ax.transAxes, verticalalignment ='top')
x_text = ax.text(0, 0, s='', transform=ax.transAxes)
y_text = ax.text(1, 0, s='', transform=ax.transAxes, verticalalignment ='bottom', 
        horizontalalignment ='right')
steps_text = ax.text(1, 1, s='', transform=ax.transAxes, verticalalignment ='top', 
        horizontalalignment ='right')
plt.grid(True, color='gray', linestyle='-', linewidth=2)

# L=plt.legend(loc=1) #Define legend objects


def update_axis(n):
    global craze
    global steps
    if n >= 10:
        craze = 0
        steps = 0
        return (0)
    elif n <= -10:
        craze = 0
        steps = 0
        return (0)
    else:
        craze += 0.01
        n -= (np.random.uniform(-1,1) + craze)
        steps += 1
        return(n)
        
def update_point(point):
    point_x = update_axis(point[0])
    point_y = update_axis(point[1])
    point = [point_x, point_y]
    return point




# Function to initialize the animation
def init():
    dot.set_data([], [])
    line.set_data([], [])
    return dot, line

# Function to update the animation on each frame
def update(frame):
    global x
    global y
    # Generate random x and y coordinates for the dot
    x = update_axis(x)
    y = update_axis(y)
    print('x = ',x,'::: y = ', y)
    
    # Update the dot and line data
    dot.set_data(x, y)
    line.set_data([0, x], [0, y])   
     
    # Calculate the distance from the center to the dot
    distance = np.sqrt(x**2 + y**2)
    
    distance_text.set_text('Distance from center: %.3f' % distance)
    steps_text.set_text('Steps from the last breach: %.1f' % (steps))
    # distance_text.set_text(s=["Distance from center:", distance])
    # global distance_text
    # distance_text = distance
    x_text.set_text('X: %.3f' % x)
    y_text.set_text('Y: %.3f' % y)

    

    
    # Print the dot's distance from the center
    # print("Distance from center:", distance)
    
    return dot, line







# Create the animation
ani = animation.FuncAnimation(fig, update, frames=100,  interval = 250, blit=True, repeat=True, save_count=100)
ani.save(filename="/tmp/pillow_example.gif", writer="pillow")

# Show the plot
plt.show()

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.MatplotlibDeprecationWarning)

craze = 0
steps = 0
x1 = np.random.uniform(-1, 1)
y1 = np.random.uniform(-1, 1)
x2 = np.random.uniform(-1, 1)
y2 = np.random.uniform(-1, 1)
# Create a figure and axis
fig, ax = plt.subplots()

# Set the limits of the plot
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])


distance_text = ''
# Create a dot object
dot1, = ax.plot([], [], 'ro')

# Create a line object
line1, = ax.plot([], [], 'b-')

dot2, = ax.plot([], [], 'ro')

# Create a line object
line2, = ax.plot([], [], 'b-')

ax.set_title('Random wondering', 
             fontsize = 14, fontweight ='bold') 
distance_text = ax.text(0, 1, s='', transform=ax.transAxes, verticalalignment ='top')
x_text = ax.text(0, 0, s='', transform=ax.transAxes)
y_text = ax.text(1, 0, s='', transform=ax.transAxes, verticalalignment ='bottom', 
        horizontalalignment ='right')
steps_text = ax.text(1, 1, s='', transform=ax.transAxes, verticalalignment ='top', 
        horizontalalignment ='right')
plt.grid(True, color='gray', linestyle='-', linewidth=2)

# L=plt.legend(loc=1) #Define legend objects


def update_axis(n):
    global craze
    global steps
    if n >= 10:
        craze = 0
        steps = 0
        return (0)
    elif n <= -10:
        craze = 0
        steps = 0
        return (0)
    else:
        craze += 0.01
        n += (np.random.uniform(-1,1) + craze)
        steps += 1
        return(n)
        
def update_point(point):
    point_x = update_axis(point[0])
    point_y = update_axis(point[1])
    point = [point_x, point_y]
    return point




# Function to initialize the animation
def init():
    dot1.set_data([], [])
    line1.set_data([], [])
    dot2.set_data([], [])
    line2.set_data([], [])
    return dot, line

# Function to update the animation on each frame
def update(frame):
    global x1
    global y1
    global x2
    global y2
    # Generate random x and y coordinates for the dot
    x1 = update_axis(x1)
    y1 = update_axis(y1)
    x2 = update_axis(x2)
    y2 = update_axis(y2)
    
    # Update the dot and line data
    dot1.set_data(x1, y1)
    dot2.set_data(x2, y2)
    line1.set_data([0, x1], [0, y1])
    line2.set_data([0, x2], [0, y2]) 
     
    # Calculate the distance from the center to the dot
    distance = np.sqrt(x**2 + y**2)
    
    distance_text.set_text('Distance from center: %.3f' % distance)
    steps_text.set_text('Steps from the last breach: %.1f' % (steps))
    # distance_text.set_text(s=["Distance from center:", distance])
    # global distance_text
    # distance_text = distance
    x_text.set_text('X: %.3f' % x)
    y_text.set_text('Y: %.3f' % y)

    

    
    # Print the dot's distance from the center
    # print("Distance from center:", distance)
    
    return dot, line







# Create the animation
ani = animation.FuncAnimation(fig, update, frames=100,  interval = 250, blit=True)
ani.save(filename="/tmp/pillow_example.gif", writer="pillow")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/matplotlib/animation.py:243, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     242 try:
# --> 243     yield self
#     244 finally:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/animation.py:1092, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1091 for anim in all_anim:
# -> 1092     anim._init_draw()  # Clear the initial frame
#    1093 frame_number = 0
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/animation.py:1749, in FuncAnimation._init_draw(self)
#    1748         return
# -> 1749     self._draw_frame(frame_data)
#    1750 else:
#
# ...
