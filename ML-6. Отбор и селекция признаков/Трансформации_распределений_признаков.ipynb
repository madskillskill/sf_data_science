# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

# %% [markdown]
# # Загрузка данных

# %%
# %%capture
# !wget https://www.dropbox.com/s/64ol9q9ssggz6f1/data_ford_price.xlsx

# %%
data = pd.read_excel('data/data_ford_price.xlsx')

# %% [markdown]
# # Трансформация признаков

# %%
plt.hist(data.year)
plt.title('Распределение признака year');

# %% [markdown]
# ## Квантильное преобразование

# %%
data_for_transform = data['year'].values.reshape((len(data),1))
 
quantile = QuantileTransformer(output_distribution='normal')
data_transformed = quantile.fit_transform(data_for_transform)
 
plt.hist(data_transformed, bins=25)
plt.title('Трансформированное распределение признака year')
plt.show()

# %%
data_for_transform = data['condition'].values.reshape((len(data),1))



quantile = QuantileTransformer(output_distribution='uniform')
data_transformed = quantile.fit_transform(data_for_transform)

display(data_transformed)

plt.hist(data_transformed, bins=25)
plt.title('Трансформированное распределение признака condition')
plt.show()
# Out:
# array([[0.96396396],
#        [0.23573574],
#        [0.23573574],
#        ...,
#        [0.67617618],
#        [0.23573574],
#        [0.23573574]])

# %%
data_transformed['condition'][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\SF\sf_data_science\ML-6. Отбор и селекция признаков\Трансформации_распределений_признаков.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/ML-6.%20%D0%9E%D1%82%D0%B1%D0%BE%D1%80%20%D0%B8%20%D1%81%D0%B5%D0%BB%D0%B5%D0%BA%D1%86%D0%B8%D1%8F%20%D0%BF%D1%80%D0%B8%D0%B7%D0%BD%D0%B0%D0%BA%D0%BE%D0%B2/%D0%A2%D1%80%D0%B0%D0%BD%D1%81%D1%84%D0%BE%D1%80%D0%BC%D0%B0%D1%86%D0%B8%D0%B8_%D1%80%D0%B0%D1%81%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B9_%D0%BF%D1%80%D0%B8%D0%B7%D0%BD%D0%B0%D0%BA%D0%BE%D0%B2.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> data_transformed['condition'][0]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data_for_transform = data['cylinders'].values.reshape((len(data),1))

display(data_for_transform)

quantile = QuantileTransformer(output_distribution='uniform')
data_transformed = quantile.fit_transform(data_for_transform)

plt.hist(data_transformed, bins=25)
plt.title('Трансформированное распределение признака cylinders')
plt.show()
# Out:
# array([[6],
#        [8],
#        [8],
#        ...,
#        [8],
#        [8],
#        [8]], dtype=int64)

# %% [markdown]
# ## Логарифмическое преобразование

# %%
plt.hist(data.price, bins=50)
plt.title('Распределение признака price');

# %%
log_price = np.log(data['price'])
 
plt.hist(log_price)
plt.title('Трансформированное распределение признака price')
plt.show()

# %%
price_data = pd.concat([data['price'], log_price.rename('transformed_price')], axis = 1)
 
price_data.describe()
# Out:
#                price  transformed_price
# count    7017.000000        7017.000000
# mean    15121.549523           9.204510
# std     11765.423119           1.275868
# min         1.000000           0.000000
# 25%      5995.000000           8.698681
# 50%     12750.000000           9.453287
# 75%     21995.000000           9.998570
# max    299500.000000          12.609870

# %%
price_data['transformed_price']
# Out:
# 0       10.689670
# 1        9.647950
# 2        7.822044
# 3        7.170120
# 4        9.537123
#           ...
# 7012    10.021271
# 7013     8.695339
# 7014     9.210240
# 7015     9.296518
# 7016     9.798127
# Name: transformed_price, Length: 7017, dtype: float64

# %% [markdown]
# ## Преобразование Бокса-Кокса

# %%
box_cox = PowerTransformer(method = 'box-cox')
 
data_box_cox = box_cox.fit_transform(data[['price', 'year']].values)
data_box_cox = pd.DataFrame(data_box_cox, columns = ['transformed_price', 'transformed_year'])
# Out:
# c:\Python\Python39\lib\site-packages\numpy\core\_methods.py:235: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# c:\Python\Python39\lib\site-packages\numpy\core\_methods.py:246: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 8), sharey=True)
axs[0][0].hist(data['price'])
axs[1][0].hist(data['year'])
axs[0][1].hist(data_box_cox['transformed_price'])
axs[1][1].hist(data_box_cox['transformed_year'])

axs[0][0].set(title='price')
axs[0][1].set(title='box cox price')

axs[1][0].set(title='year')
axs[1][1].set(title='box cox year')

fig.suptitle('Сравнение распределений до трансформации и после')

plt.show()
