# %%
import pandas as pd
import numpy as np

# %%
hotels = pd.read_csv('data/hotels.csv')
hotels.head(3)
# Out:
#                                        hotel_address  \
# 0  Stratton Street Mayfair Westminster Borough Lo...
# 1  130 134 Southampton Row Camden London WC1B 5AF...
# 2   151 bis Rue de Rennes 6th arr 75006 Paris France
#
#    additional_number_of_scoring review_date  average_score  \
# 0                           581   2/19/2016            8.4
# 1                           299   1/12/2017            8.3
# 2                            32  10/18/2016            8.9
#
#                           hotel_name reviewer_nationality  \
# 0                 The May Fair Hotel      United Kingdom
# 1    Mercure London Bloomsbury Hotel      United Kingdom
# 2  Legend Saint Germain by Elegancia               China
#
#        negative_review  review_total_negative_word_counts  \
# 0             Leaving                                   3
# 1       poor breakfast                                  3
# 2   No kettle in room                                   6
#
#    total_number_of_reviews      positive_review  \
# 0                     1994   Staff were amazing
# 1                     1361             location
# 2                      406          No Positive
#
#    review_total_positive_word_counts  \
# 0                                  4
# 1                                  2
# 2                                  0
#
#    total_number_of_reviews_reviewer_has_given  reviewer_score  \
# 0                                           7            10.0
# 1                                          14             6.3
# 2                                          14             7.5
#
#                                                 tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Studio Suite ...           531 day
# 1  [' Business trip ', ' Couple ', ' Standard Dou...           203 day
# 2  [' Leisure trip ', ' Solo traveler ', ' Modern...           289 day
#
#          lat       lng
# 0  51.507894 -0.143671
# 1  51.521009 -0.123097
# 2  48.845377  2.325643

# %%
display(hotels['reviewer_score'].info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 386803 entries, 0 to 386802
# Series name: reviewer_score
# Non-Null Count   Dtype
# --------------   -----
# 386803 non-null  float64
# dtypes: float64(1)
# memory usage: 3.0 MB
# None

# %%
import matplotlib.pyplot as plt

fig = plt.scatter(
    data=hotels,
    x='average_score',
    y='total_number_of_reviews')
plt.suptitle('Отношение возраста и опыта работы', fontsize=24)
plt.xlabel('Возраст', fontsize=18)
plt.ylabel('Опыт работы', fontsize=18)
plt.show(fig)

#display(hotels[hotels['reviewer_score']<3.4])

# %%
hotels['negative_review'] = hotels['negative_review'].str.strip()
hotels['positive_review'] = hotels['positive_review'].str.strip()

# %%
display(hotels['positive_review'].value_counts())
display(hotels['negative_review'].value_counts())
# Out:
# No Positive                                                                                                                                                                                          26885
# Location                                                                                                                                                                                              7496
# Everything                                                                                                                                                                                            2146
# location                                                                                                                                                                                              1296
# Nothing                                                                                                                                                                                               1101
#                                                                                                                                                                                                      ...
# The smell in reception area and rooms can be better than now                                                                                                                                             1
# Front desk staff was extremely helpful and helped to plan our touring of Milan Even made reservations for dinner for us                                                                                  1
# The personel was really helpful and with a good and positive attitude The breakfast was good and the room was clean Not that big though Excellent location Overall good quality staying in London        1
# Location Helping staff Washroom                                                                                                                                                                          1
# Beds comfortable Pillows also good Homely feel although room was small Staff very pleasant and helpful thank you                                                                                         1
# Name: positive_review, Length: 307958, dtype: int64
# No Negative                                                                                                                                                                                                                                                                                                                                                                                                                           95907
# Nothing                                                                                                                                                                                                                                                                                                                                                                                                                               13891
# nothing                                                                                                                                                                                                                                                                                                                                                                                                                                1879
# None                                                                                                                                                                                                                                                                                                                                                                                                                                    871
# N A                                                                                                                                                                                                                                                                                                                                                                                                                                     818
#                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# We were supposed to have a cake in our room on arrival and nothing was there I had to ring down and ask for it which ruined the suprise a little for my partner                                                                                                                                                                                                                                                                           1
# Rooms are extremely small You can only get into the double bed from one side walls on the other 3 so you have to climb over or wake your partner if you want to get up in the night First room we were given was next to a unbelievably loud generator we were moved to the only other available room which was quiet but stank of cigarette smoke Breakfast was awful Not what you expect when you see the photos on the web site        1
# Better coffee                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Also bar staff mean with non alcoholic drink in bar just ice and mint in short class not value for money                                                                                                                                                                                                                                                                                                                                  1
# Patio outside could have been cleaned of algae to give a more uplifting atmosphere to a downstairs room                                                                                                                                                                                                                                                                                                                                   1
# Name: negative_review, Length: 246248, dtype: int64

# %%
print(hotels['hotel_address'][1])
# Out:
# 130 134 Southampton Row Camden London WC1B 5AF United Kingdom

# %% [markdown]
# **review_score to category**

# %%
counter = 0

average_score_preserved_mapper = dict()

for i in sorted(set(hotels['average_score'])):
    average_score_preserved_mapper.update({i:counter})
    counter += 1

print(average_score_preserved_mapper)
# Out:
# {5.2: 0, 6.4: 1, 6.6: 2, 6.7: 3, 6.8: 4, 6.9: 5, 7.0: 6, 7.1: 7, 7.2: 8, 7.3: 9, 7.4: 10, 7.5: 11, 7.6: 12, 7.7: 13, 7.8: 14, 7.9: 15, 8.0: 16, 8.1: 17, 8.2: 18, 8.3: 19, 8.4: 20, 8.5: 21, 8.6: 22, 8.7: 23, 8.8: 24, 8.9: 25, 9.0: 26, 9.1: 27, 9.2: 28, 9.3: 29, 9.4: 30, 9.5: 31, 9.6: 32, 9.8: 33}

# %%
hotels['average_score'] = hotels['average_score'].replace(average_score_preserved_mapper)
hotels['average_score'] = hotels['average_score'].astype(int)

# %% [markdown]
# **Take both city and country from address**

# %%
from collections import deque

countrified = pd.DataFrame()

def countrifier(string):
    cut = deque(string.split()[-5:])
    country = cut[-1]
    city = cut[-2]
    if country == 'Kingdom':
        country = 'United Kingdom'
        city = cut[0]
    return pd.Series({'country': country, 'city': city})

hotels[['country', 'city']] = hotels['hotel_address'].apply(countrifier)
display(hotels[['country', 'city']].describe())
# Out:
#                country    city
# count           386803  386803
# unique               6       6
# top     United Kingdom  London
# freq            196774  196774

# %%
display(hotels['city'].value_counts())
display(hotels['country'].value_counts())
# Out:
# London       196774
# Barcelona     45132
# Paris         44830
# Amsterdam     43006
# Vienna        29178
# Milan         27883
# Name: city, dtype: int64
# United Kingdom    196774
# Spain              45132
# France             44830
# Netherlands        43006
# Austria            29178
# Italy              27883
# Name: country, dtype: int64

# %%
import seaborn as sns
import matplotlib
# %matplotlib inline
sns.heatmap(hotels.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Как мы видим, Страна == Город для всего датафрейма.

# %%
def citifier(string):
    cut = string.split()[::-1]

    country = cut[1]

    country = country[0]

    if country == 'Kingdom':
        city = cut[3:]
    else: city = cut[2:]
    
    city = city[0]
    
    return city

hotels['hotel_city'] = hotels['hotel_address'].apply(citifier)

display(hotels['hotel_city'].value_counts())
# Out:
# 1010     9320
# 20124    8803
# 75008    8284
# 08002    7614
# 75001    4120
#          ...
# 1230       17
# JW         16
# 20141      13
# 7DD         9
# 92120       5
# Name: hotel_city, Length: 566, dtype: int64

# %%
def ws_cutter(string):
    string = string[1:-1]
    return(string)

hotels['reviewer_nationality'] =\
    hotels['reviewer_nationality'].apply(ws_cutter)

# %%
hotels['is_homeland'] = (hotels['country']==hotels['reviewer_nationality'])
comp_pd = pd.DataFrame()
comp_pd['nat'], comp_pd['htl'], comp_pd['=='] =\
    hotels['reviewer_nationality'], hotels['country'], hotels['is_homeland']
display(hotels[['country', 'reviewer_nationality', 'is_homeland']].head(3))
# Out:
#           country reviewer_nationality  is_homeland
# 0  United Kingdom       United Kingdom         True
# 1  United Kingdom       United Kingdom         True
# 2          France                China        False

# %%
hotels['city'], hotels['country'] =\
    hotels['city'].astype('category'),\
        hotels['country'].astype('category')

city_dict = {'London':0, 'Barcelona':1, 'Paris':2,
    'Amsterdam':3, 'Vienna':4, 'Milan':5}
country_dict = {'United Kingdom':0, 'Spain':1, 'France':2,
                'Netherland':3, 'Austria':4,'Italy':5}

hotels['city'] = hotels['city'].cat.rename_categories(city_dict)
hotels['country'] = hotels['city'].cat.rename_categories(city_dict)

# %%
hotels['city_int'] = hotels['city'].astype(int)
hotels['country_int'] = hotels['city'].astype(int)

# %%
sns.scatterplot(data=hotels, x='city_int', y='country_int')
# Out:
# <AxesSubplot:xlabel='city_int', ylabel='country_int'>

# %% [markdown]
# **hotel_country categorize**

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 23 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               386803 non-null  object
#  1   additional_number_of_scoring                386803 non-null  int64
#  2   review_date                                 386803 non-null  object
#  3   average_score                               386803 non-null  int32
#  4   hotel_name                                  386803 non-null  object
#  5   reviewer_nationality                        386803 non-null  object
#  6   negative_review                             386803 non-null  object
#  7   review_total_negative_word_counts           386803 non-null  int64
#  8   total_number_of_reviews                     386803 non-null  int64
#  9   positive_review                             386803 non-null  object
#  10  review_total_positive_word_counts           386803 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  12  reviewer_score                              386803 non-null  float64
#  13  tags                                        386803 non-null  object
#  14  days_since_review                           386803 non-null  object
#  15  lat                                         384355 non-null  float64
#  16  lng                                         384355 non-null  float64
#  17  country                                     386803 non-null  category
#  18  city                                        386803 non-null  category
#  19  hotel_city                                  386803 non-null  object
#  20  is_homeland                                 386803 non-null  bool
#  21  city_int                                    386803 non-null  int32
#  22  country_int                                 386803 non-null  int32
# dtypes: bool(1), category(2), float64(3), int32(3), int64(5), object(9)
# memory usage: 55.7+ MB

# %% [markdown]
# **days_since_review**

# %%
hotels['days_since_review'] = ((pd.to_datetime('2017-08-04')\
    -pd.to_datetime(hotels['review_date']))/ np.timedelta64(1, 'D'))
print(hotels['days_since_review'][0])
# Out:
# 532.0

# %% [markdown]
# **effing tags (I really really hate 'em)**

# %%
def rev_func(num_tags):
    num_tags = num_tags[2:-2]
    res = num_tags.strip().split(' \', \' ')
    return res

hotels['tags_n'] = hotels['tags'].apply(rev_func)

# %% [markdown]
# **nights counter**

# %%
hotels['nights'] = 1

def nights_counter(tags_listed):
    for i in tags_listed:
        if i[0] == 'S':
            if i[1] == 't':
                if i[2] == 'a':
                    if i[3] == 'y':
                        return int(i[7:9])

hotels['nights'] = hotels['tags_n'].apply(nights_counter)
display(hotels['nights'].describe())
# Out:
# count    386657.000000
# mean          2.361571
# std           1.646506
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          30.000000
# Name: nights, dtype: float64

# %% [markdown]
# **cutting off insignificant amount of nights**

# %%
#hotels['nights'] = hotels['nights'].astype(int)
hotels['nights'] = hotels['nights'].apply(lambda x: x if x < 14 else 15)
hotels['nights'].value_counts()
# Out:
# 1.0     145373
# 2.0     100263
# 3.0      72000
# 4.0      35748
# 5.0      15611
# 6.0       7399
# 7.0       5549
# 8.0       1910
# 9.0        966
# 10.0       663
# 15.0       624
# 11.0       306
# 12.0       217
# 13.0       174
# Name: nights, dtype: int64

# %% [markdown]
# **free wifi anyone?**

# %%
wifi_db = pd.DataFrame()

wifi_db[['positive_review', 'tags_n']] = hotels[['positive_review', 'tags_n']].copy()

wifi_db['tags_n'].str.lower()

hotels['wifi'] = False

def wifi_detector(tags_listed):
    for i in tags_listed:
        if 'wifi' in i:
            return True
        
        
        

wifi_db['wifi'] = wifi_db['tags_n'].apply(wifi_detector)
display(wifi_db['wifi'].describe())
# Out:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: wifi, dtype: object

# %%
htl = pd.DataFrame()
htl = hotels[['nights','average_score','reviewer_score']].copy()

# %%
sns.set(rc={"figure.figsize":(14, 14)})
sns.heatmap(hotels.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## ***IT'S A FINAL COUNTDOWN***

# %%
from playsound import playsound
playsound('Europe - The Final Countdown (Official Video).mp3', block=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\SF\sf_data_science\PROJECT-3\P3.ipynb Cell 37 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PROJECT-3/P3.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> from playsound import playsound
#       <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PROJECT-3/P3.ipynb#X51sZmlsZQ%3D%3D?line=1'>2</a> playsound('Europe - The Final Countdown (Official Video).mp3', block=False)
#
# ModuleNotFoundError: No module named 'playsound'

# %%
object_columns = [s for s in hotels.columns if hotels[s].dtypes == 'object']
hotels.drop(object_columns, axis = 1, inplace=True)


hotels = hotels.fillna(0)

hotels.drop(['lat', 'lng', 'review_total_positive_word_counts'], axis=1, inplace=True)

# %%
# Разбиваем датафрейм на части, необходимые для обучения и тестирования модели  
# Х - данные с информацией об отелях, у - целевая переменная (рейтинги отелей)  
X = hotels.drop(['reviewer_score'], axis = 1)  
y = hotels['reviewer_score']

# %%
# Загружаем специальный инструмент для разбивки:  
from sklearn.model_selection import train_test_split

# %%
# Наборы данных с меткой "train" будут использоваться для обучения модели, "test" - для тестирования.  
# Для тестирования мы будем использовать 25% от исходного датасета.  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96701 entries, 177225 to 152014
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   additional_number_of_scoring                96701 non-null  int64
#  1   average_score                               96701 non-null  int32
#  2   review_total_negative_word_counts           96701 non-null  int64
#  3   total_number_of_reviews                     96701 non-null  int64
#  4   total_number_of_reviews_reviewer_has_given  96701 non-null  int64
#  5   days_since_review                           96701 non-null  float64
#  6   country                                     96701 non-null  category
#  7   city                                        96701 non-null  category
#  8   is_homeland                                 96701 non-null  bool
#  9   city_int                                    96701 non-null  int32
#  10  country_int                                 96701 non-null  int32
#  11  nights                                      96701 non-null  float64
# dtypes: bool(1), category(2), float64(2), int32(3), int64(4)
# memory usage: 6.5 MB

# %%
# Импортируем необходимые библиотеки:  
from sklearn.ensemble import RandomForestRegressor # инструмент для создания и обучения модели  
from sklearn import metrics # инструменты для оценки точности модели  
  
# Создаём модель  
regr = RandomForestRegressor(n_estimators=100)  
      
# Обучаем модель на тестовом наборе данных  
regr.fit(X_train, y_train)  
      
# Используем обученную модель для предсказания рейтинга отелей в тестовой выборке.  
# Предсказанные значения записываем в переменную y_pred  
y_pred = regr.predict(X_test)

# %% [markdown]
# MAPE: 0.14134178189311136
#
# MAPE: 0.14131385806717026
#
# MAPE: 0.14053156733726535
#
# MAPE: 0.14070534667401732
#
# MAPE: 0.1405255170406278
#
# MAPE: 0.13755135308025937
#
# MAPE: 0.13739329046723142
#
# MAPE: 0.13732568793244715

# %%
# Сравниваем предсказанные значения (y_pred) с реальными (y_test), и смотрим насколько они отличаются  
# Метрика называется Mean Absolute Percentage Error (MAPE) и показывает среднюю абсолютную процентную ошибку предсказанных значений от фактических.  
print('MAPE:', metrics.mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MAPE: 0.15535215821835097

# %% [markdown]
# Небольшой бонус:

# %%
# # убираем признаки которые еще не успели обработать, 
# # модель на признаках с dtypes "object" обучаться не будет, просто выберим их и удалим
# object_columns = [s for s in hotels.columns if hotels[s].dtypes == 'object']
# hotels.drop(object_columns, axis = 1, inplace=True)

# # заполняем пропуски самым простым способом
# hotels = hotels.fillna(0)
