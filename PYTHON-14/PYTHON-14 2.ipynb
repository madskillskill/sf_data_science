# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('default')

covid_df = pd.read_csv('data/covid_data.csv', sep=',')
us_data = covid_df[covid_df['country'] == 'United States']

fig = plt.figure(figsize=(8, 4))
axes = fig.add_axes([0, 0, 1, 1])
axes.scatter(
    x=us_data['people_fully_vaccinated'], 
    y=us_data['daily_confirmed'], 
    s=100,
    marker='o',
    c = 'blue'
);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Program Files\Python38\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File c:\Program Files\Python38\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Program Files\Python38\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'people_fully_vaccinated'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\SF\sf_data_science\PYTHON-14\PYTHON-14 2.ipynb Cell 1' in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PYTHON-14/PYTHON-14%202.ipynb#ch0000000?line=10'>11</a> fig = plt.figure(figsize=(8, 4))
#      <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PYTHON-14/PYTHON-14%202.ipynb#ch0000000?line=11'>12</a> axes = fig.add_axes([0, 0, 1, 1])
#      <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PYTHON-14/PYTHON-14%202.ipynb#ch0000000?line=12'>13</a> axes.scatter(
# ---> <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PYTHON-14/PYTHON-14%202.ipynb#ch0000000?line=13'>14</a>     x=us_data['people_fully_vaccinated'],
#      <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PYTHON-14/PYTHON-14%202.ipynb#ch0000000?line=14'>15</a>     y=us_data['daily_confirmed'],
#      <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PYTHON-14/PYTHON-14%202.ipynb#ch0000000?line=15'>16</a>     s=100,
#      <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PYTHON-14/PYTHON-14%202.ipynb#ch0000000?line=16'>17</a>     marker='o',
#      <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PYTHON-14/PYTHON-14%202.ipynb#ch0000000?line=17'>18</a>     c = 'blue'
#      <a href='vscode-notebook-cell:/c%3A/SF/sf_data_science/PYTHON-14/PYTHON-14%202.ipynb#ch0000000?line=18'>19</a> )
#
# File c:\Program Files\Python38\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File c:\Program Files\Python38\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///c%3A/Program%20Files/Python38/lib/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'people_fully_vaccinated'
